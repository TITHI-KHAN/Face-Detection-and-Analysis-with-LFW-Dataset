# %%
import warnings
warnings.filterwarnings('ignore') # Ignore warnings for cleaner output
import os
import random
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set the path to the dataset directory
data_dir_path = "/kaggle/input/lfw-dataset/"
os.makedirs(data_dir_path, exist_ok=True) # Create the directory if it doesn't exist
all_files = os.listdir(data_dir_path)
all_files
# Out:
# ['mismatchpairsDevTrain.csv',
#  'matchpairsDevTest.csv',
#  'pairs.csv',
#  'lfw_allnames.csv',
#  'peopleDevTest.csv',
#  'lfw-deepfunneled',
#  'people.csv',
#  'peopleDevTrain.csv',
#  'mismatchpairsDevTest.csv',
#  'lfw_readme.csv',
#  'matchpairsDevTrain.csv']

# %%
# Define the path to the images directory
images_data_dir = os.path.join(data_dir_path, 'lfw-deepfunneled', 'lfw-deepfunneled')

# %%
# Get the list of persons (directories) in the images directory
persons = os.listdir(images_data_dir)

# %%
len(persons)
# Out:
# 5749

# %%
# Choose a random person from the dataset
random_person = random.choice(persons)
random_person
# Out:
# 'Ann_Veneman'

# %%
# Select some images from the random person's directory
image_select = os.listdir(os.path.join(images_data_dir, random_person))
image_select
# Out:
# ['Ann_Veneman_0003.jpg',
#  'Ann_Veneman_0005.jpg',
#  'Ann_Veneman_0009.jpg',
#  'Ann_Veneman_0004.jpg',
#  'Ann_Veneman_0002.jpg',
#  'Ann_Veneman_0011.jpg',
#  'Ann_Veneman_0008.jpg',
#  'Ann_Veneman_0001.jpg',
#  'Ann_Veneman_0006.jpg',
#  'Ann_Veneman_0007.jpg',
#  'Ann_Veneman_0010.jpg']

# %%
sample = image_select[:5]

# Extract properties of selected images (name, size, format)
image_properties = []
for image_name in sample:
    image_path = os.path.join(images_data_dir, random_person, image_name)
    img = Image.open(image_path)
    image_properties.append((image_name, img.size, img.format))

# %%
image_properties
# Out:
# [('Ann_Veneman_0003.jpg', (250, 250), 'JPEG'),
#  ('Ann_Veneman_0005.jpg', (250, 250), 'JPEG'),
#  ('Ann_Veneman_0009.jpg', (250, 250), 'JPEG'),
#  ('Ann_Veneman_0004.jpg', (250, 250), 'JPEG'),
#  ('Ann_Veneman_0002.jpg', (250, 250), 'JPEG')]

# %%
# Choose 5 random persons from the dataset
random_person = random.sample(persons, 5)

# %%
random_person
# Out:
# ['Jennifer_Capriati',
#  'Floyd_Mayweather',
#  'Dimitar_Berbatov',
#  'Michael_Friedman',
#  'Judy_Locy']

# %%
# Select one random image from each of the 5 random persons
select_images = []
for person in random_person:
    person_dir = os.path.join(images_data_dir, person)
    person_file = os.listdir(person_dir)
    select_person_image_file = random.choice(person_file)
    select_images.append(os.path.join(person_dir, select_person_image_file))
    
select_images
# Out:
# ['/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Jennifer_Capriati/Jennifer_Capriati_0032.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Floyd_Mayweather/Floyd_Mayweather_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Dimitar_Berbatov/Dimitar_Berbatov_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Michael_Friedman/Michael_Friedman_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Judy_Locy/Judy_Locy_0001.jpg']

# %%
a = '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Akhmed_Zakayev/Akhmed_Zakayev_0003.jpg'
a.split('/')[-2]
# Out:
# 'Akhmed_Zakayev'

# %%
# Display the selected images
fig, axs = plt.subplots(1, 5, figsize = (15, 3))
for i, image_path in enumerate(select_images):
    img = mpimg.imread(image_path)
    axs[i].imshow(img)
    axs[i].set_title(select_images[i].split('/')[-2]) # Extract person's name from the path
    axs[i].axis('off')
    
plt.show()

# %%
random_person = np.random.choice(persons, 15, replace = False) # replace = False means no duplicate.
select_images = []
for person in random_person:
    person_dir = os.path.join(images_data_dir, person)
    person_file = os.listdir(person_dir)
    select_person_image_file = random.choice(person_file)
    select_images.append(os.path.join(person_dir, select_person_image_file))
    
select_images
# Out:
# ['/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Hitoshi_Oshitani/Hitoshi_Oshitani_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/George_Karl/George_Karl_0002.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Len_Jenoff/Len_Jenoff_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Nora_Ephron/Nora_Ephron_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Brad_Garrett/Brad_Garrett_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Khaled_Sawalhi/Khaled_Sawalhi_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Vanessa_Incontrada/Vanessa_Incontrada_0003.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Ruth_Bader_Ginsburg/Ruth_Bader_Ginsburg_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Carol_Williams/Carol_Williams_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Bob_Herz/Bob_Herz_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Humberto_Coelho/Humberto_Coelho_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Bob_Hayes/Bob_Hayes_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Steven_Craig/Steven_Craig_0001.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Miguel_Contreras/Miguel_Contreras_0002.jpg',
#  '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Alicia_Keys/Alicia_Keys_0001.jpg']

# %%
fig, axs = plt.subplots(3, 5, figsize = (15, 9))
for i, image_path in enumerate(select_images):
    img = mpimg.imread(image_path)
    axs[i // 5, i % 5].imshow(img)
    axs[i // 5, i % 5].set_title(select_images[i].split('/')[-2])
    axs[i // 5, i % 5].axis('off')
    
plt.show()

# %%
import pandas as pd

# Read metadata about the dataset
allNames = pd.read_csv("/kaggle/input/lfw-dataset/lfw_allnames.csv")

# Plot a histogram of the number of images per person
plt.figure(figsize = (10, 6))
plt.hist(allNames['images'], bins = 50, color = "blue", edgecolor="black")
plt.title("Image Count")
plt.xlabel("NUmber of Images")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Display summary statistics of the number of images per person
allNames["images"].describe()
# Out:
# count    5749.000000
# mean        2.301792
# std         9.016410
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       530.000000
# Name: images, dtype: float64

# %%
# Load an example image and perform face detection
import cv2
image = cv2.imread('/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Abdul_Rahman/Abdul_Rahman_0001.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Use Haar Cascade classifier for face detection
face_detect = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = face_detect.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Draw bounding boxes around detected faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w ,y+h), (255, 0, 0), 2) # thickness of rectangle = 2.
    
# Display the image with bounding boxes    
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Plotting images with bounding boxes
fig, axs = plt.subplots(3, 5, figsize=(15, 9))
for i, image_path in enumerate(select_images):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
     # Detect faces in the image
    face_detect = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    faces = face_detect.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    # Draw bounding boxes around detected faces
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    
    axs[i // 5, i % 5].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    axs[i // 5, i % 5].set_title(image_path.split('/')[-2]) # Extract person's name from the path
    axs[i // 5, i % 5].axis('off')
    axs[i // 5, i % 5].axis('off')

plt.show()
